# %% [markdown]
# Gauss-Test
# --
#
#
# Ein Gauss-Test untersucht den Mittelwert $\bar x$ einer Stichprobe von Umfang $k$ und vergleicht diesen Mittelwert mit dem Erwartungswert $\mu$ der Normalverteilung mit Standardabweichung $\sigma$, aus der die Daten stammen. Dieser Mittelwert  $\bar x$ ist je nach Stichprobe unterschiedlich, der Mittelwert $\bar x$ unterliegt also ebenfalls einer eigenen Verteilung, und zwar einer Normalverteilung mit Erwartungswert $\mu$ und Standardabweichung $\frac{\sigma}{\sqrt{k}}$.
#
# Mit diesem Aufgabenblatt können Sie veranschaulichen, wie sich die Stichprobengröße auf den Fehler 1. Art auswirkt.
# Simulieren Sie dazu Daten für den Kraftstoffverbrauch eines PKWs und stellen Sie den Fehler 1. Art graphisch dar.
#
# Schreiben Sie dazu eine Python - Funktion *kraftstoff*, die als Eingabewerte zwei ganze Zahlen $n$ und $k$ erhält und Histogramme mit zugehörigen Dichten der Normalverteilung plottet.
#
#
# Führen Sie dann die Python-Funktion aus für $n=100, k=30$, $n=100, k=100$ und $n=500, k=30$ und vergleichen Sie jeweils  die überlappenden Flächen der Histogramme bzw. der Normalverteilungskurven. Was sagt dies über den Fehler erster Art aus?

# %%
#########################
# Funktion kraftstoff
#######
# Eingabewerte
# k Größe der Stichprobe
# n  Anzahl Simulationen
########
# Ausgabe
# Graphik
#########################

def kraftstoff(n,k):

    import numpy as np
    from scipy.stats import norm # for normal distribution
    import matplotlib.pyplot as plt #Graphik Package
    
    #Initialisierung der Mittelwert - Vektoren
    myMeans1=np.zeros(n)
    myMeans2=
    
    # Simulation von Verbrauchsdaten durch normalverteilte Zufallszahlen
    # mit zwei verschiedenen Erwartungswerten
    # Berechnung der zugehörigen Mittelwerte
    for i in range(n):
        data1=np.round(norm.rvs(6.4, 0.7, k),2)
        myMeans1[i]=np.mean(data1)
        data2=np.round(  )
        myMeans2[i]=

    # graphische Veranschaulichung
    plt.figure()

    # Histogramm mit zugehöriger Dichte für Erwartungswert 6.4
    plt.hist(myMeans1,density=True,alpha=0.5)
    fit1 = norm.pdf(np.arange(min(myMeans1), max(myMeans1) +0.1, 0.01),6.4, 0.7/np.sqrt(k)) 
    plt.plot(np.arange(min(myMeans1), max(myMeans1)+0.1 , 0.01),fit1,'-o')

    # Histogramm mit zugehöriger Dichte für Erwartungswert 6.6
    
    plt.hist(   )
    fit2 = norm.pdf(   ,    ,    )  
    plt.plot(   ,   ,'-o')  
    
    # Festlegung des Bereichs für y-Werte, Titel, Achsenbeschriftungen
    Y= np.max(np.concatenate((fit1,fit2)))
    plt.ylim(0,Y)
    plt.title('   ' %(n ,k))
    plt.xlabel('  ')
    plt.ylabel('  ')
    plt.show()

# %%
kraftstoff(100,100)
